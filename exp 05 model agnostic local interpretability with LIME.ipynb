# %%
# !pip install LIME
# Out:
# Looking in indexes: https://pypi.org/simple, https://www.piwheels.org/simple
# Collecting LIME
#   Downloading https://archive1.piwheels.org/simple/lime/lime-0.2.0.1-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.8/283.8 kB 455.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /home/pi/base/lib/python3.11/site-packages (from LIME) (3.10.7)
# Requirement already satisfied: numpy in /home/pi/base/lib/python3.11/site-packages (from LIME) (2.3.4)
# Requirement already satisfied: scikit-image>=0.12 in /home/pi/base/lib/python3.11/site-packages (from LIME) (0.25.2)
# Requirement already satisfied: scikit-learn>=0.18 in /home/pi/base/lib/python3.11/site-packages (from LIME) (1.7.2)
# Requirement already satisfied: scipy in /home/pi/base/lib/python3.11/site-packages (from LIME) (1.15.3)
# Collecting tqdm
#   Downloading https://www.piwheels.org/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 182.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: networkx>=3.0 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (3.5)
# Requirement already satisfied: pillow>=10.1 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (12.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/pi/base/lib/python3.11/site-packages (from scikit-image>=0.12->LIME) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /home/pi/base/lib/python3.11/site-packages (from scikit-learn>=0.18->LIME) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/pi/base/lib/python3.11/site-packages (from scikit-learn>=0.18->LIME) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/pi/base/lib/python3.11/site-packages (from matplotlib->LIME) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/pi/base/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->LIME) (1.17.0)
# Installing collected packages: tqdm, LIME
# Successfully installed LIME-0.2.0.1 tqdm-4.67.1

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
from lime.lime_tabular import LimeTabularExplainer

# %%
data = load_breast_cancer()

# %%
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %%
data.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error',
#        'fractal dimension error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
cols = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness']
X = X[cols]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=200, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)

# %%
# Choose and instance
inst_idx = 3
x = X_test.iloc[inst_idx].values

# %%
explainer = LimeTabularExplainer(
    training_data=X_train.values,
    feature_names=cols,
    class_names=['malignant', 'benign'],
    mode='classification',
    discretize_continuous=True
)

# %%
exp = explainer.explain_instance(x, clf.predict_proba, num_features=5)
# Out:
# /home/pi/base/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Predicted probabilities: ", clf.predict_proba([x])[0])
print("\nLIME explanation (feature, weight): ")
for feat, weight in exp.as_list():
    print(feat, weight)
# Out:
# Predicted probabilities:  [0.025 0.975]
#
# LIME explanation (feature, weight):
# mean smoothness > 0.10 -0.17410760044165377
# 75.50 < mean perimeter <= 85.94 0.14015631634599623
# 421.65 < mean area <= 545.65 0.08028826274454114
# 11.72 < mean radius <= 13.27 0.04127126304284745
# 16.18 < mean texture <= 18.69 0.035486335157979707
# /home/pi/base/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
